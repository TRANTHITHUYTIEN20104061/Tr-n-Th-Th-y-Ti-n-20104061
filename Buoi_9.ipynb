# %% [markdown]
# <a href="https://colab.research.google.com/github/TRANTHITHUYTIEN20104061/Tr-n-Th-Th-y-Ti-n-20104061/blob/main/Buoi_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (Multi-task Cascaded Convolutional Networks)

# %%
# !git clone https://github.com/ipazc/mtcnn.git
# !git clone https://github.com/ageitgey/face_recognition.git
# Out:
# Cloning into 'mtcnn'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 221 (delta 8), reused 14 (delta 5), pack-reused 194
# Receiving objects: 100% (221/221), 2.82 MiB | 7.18 MiB/s, done.
# Resolving deltas: 100% (112/112), done.
# Cloning into 'face_recognition'...
# remote: Enumerating objects: 1022, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 1022 (delta 2), reused 6 (delta 2), pack-reused 1014
# Receiving objects: 100% (1022/1022), 101.51 MiB | 27.36 MiB/s, done.
# Resolving deltas: 100% (583/583), done.

# %%
# !apt-get install build-essential cmake
# !apt-get install libopenblas-dev liblapack-dev 
# !pip3 install dlib
# !pip3 install face_recognition
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# liblapack-dev is already the newest version (3.7.1-4ubuntu1).
# libopenblas-dev is already the newest version (0.2.20+ds-4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip3 install mtcnn
# !pip3 install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 6.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from mtcnn import MTCNN

# %%
import matplotlib.pyplot as plt

# %%
url='/content/z3845227179737_7646631a4cc92a4995a4d9f667d44c51.jpg'
pixels= plt.imread(url)

# %%
detector= MTCNN()
faces=detector.detect_faces(pixels)
# Out:
# ...
# 5/5 [==============================] - 0s 39ms/step

# %%
for face in faces:
  print(faces)
# Out:
# [{'box': [880, 890, 79, 101], 'confidence': 0.999999463558197, 'keypoints': {'left_eye': (902, 932), 'right_eye': (939, 930), 'nose': (921, 953), 'mouth_left': (907, 968), 'mouth_right': (938, 965)}}, {'box': [979, 590, 52, 63], 'confidence': 0.999997079372406, 'keypoints': {'left_eye': (995, 614), 'right_eye': (1019, 614), 'nose': (1008, 624), 'mouth_left': (998, 639), 'mouth_right': (1018, 639)}}, {'box': [1134, 627, 52, 66], 'confidence': 0.9999909996986389, 'keypoints': {'left_eye': (1149, 653), 'right_eye': (1174, 654), 'nose': (1161, 667), 'mouth_left': (1146, 673), 'mouth_right': (1172, 674)}}, {'box': [1577, 654, 58, 81], 'confidence': 0.9999826550483704, 'keypoints': {'left_eye': (1585, 684), 'right_eye': (1605, 688), 'nose': (1580, 698), 'mouth_left': (1578, 717), 'mouth_right': (1595, 719)}}, {'box': [1743, 651, 68, 86], 'confidence': 0.9999682307243347, 'keypoints': {'left_eye': (1754, 680), 'right_eye': (1784, 683), 'nose': (1762, 701), 'mouth_left': (1754, 713), 'mouth_
# ...

# %%
pixels= plt.imread('/content/images.jpg')
detector= MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 1/1 [==============================] - 0s 132ms/step
# {'box': [57, 16, 56, 77], 'confidence': 0.999871015548706, 'keypoints': {'left_eye': (65, 47), 'right_eye': (90, 48), 'nose': (71, 64), 'mouth_left': (66, 76), 'mouth_right': (87, 77)}}

# %%
pixels= plt.imread('/content/tải xuống.jpg')
detector= MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 3/3 [==============================] - 0s 40ms/step
# {'box': [42, 100, 23, 28], 'confidence': 0.9417437314987183, 'keypoints': {'left_eye': (52, 112), 'right_eye': (62, 111), 'nose': (60, 117), 'mouth_left': (55, 125), 'mouth_right': (62, 124)}}
# {'box': [9, 131, 21, 28], 'confidence': 0.9349924921989441, 'keypoints': {'left_eye': (19, 143), 'right_eye': (27, 142), 'nose': (26, 148), 'mouth_left': (21, 155), 'mouth_right': (26, 154)}}
# {'box': [107, 187, 23, 31], 'confidence': 0.7305152416229248, 'keypoints': {'left_eye': (118, 200), 'right_eye': (127, 199), 'nose': (126, 204), 'mouth_left': (120, 210), 'mouth_right': (127, 210)}}

# %%
pixels= plt.imread('/content/z3882537572977_29bbf567cebd01fd7537d8071dbe78b9.jpg')
detector= MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 3/3 [==============================] - 0s 24ms/step
# {'box': [189, 409, 25, 30], 'confidence': 0.9999967217445374, 'keypoints': {'left_eye': (197, 422), 'right_eye': (208, 420), 'nose': (204, 427), 'mouth_left': (200, 433), 'mouth_right': (209, 430)}}
# {'box': [700, 402, 22, 27], 'confidence': 0.9999961256980896, 'keypoints': {'left_eye': (705, 411), 'right_eye': (716, 412), 'nose': (709, 416), 'mouth_left': (705, 422), 'mouth_right': (715, 422)}}
# {'box': [789, 398, 25, 29], 'confidence': 0.9999906420707703, 'keypoints': {'left_eye': (796, 409), 'right_eye': (808, 409), 'nose': (802, 415), 'mouth_left': (796, 420), 'mouth_right': (807, 420)}}
# {'box': [827, 395, 25, 29], 'confidence': 0.999981701374054, 'keypoints': {'left_eye': (834, 406), 'right_eye': (845, 407), 'nose': (839, 412), 'mouth_left': (833, 416), 'mouth_right': (845, 417)}}
# ...

# %%
url='/content/z3845227179737_7646631a4cc92a4995a4d9f667d44c51.jpg'
pixels= plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(plt.imread(url))
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height, fill = False, color = 'red')
  ax.add_patch(rect)
plt.show()
for key, value in face['keypoints'].item():
  dot=plt.Circle(value, radius=2, color='red')
  ax.add_patch()
# Out:
# ...
# 5/5 [==============================] - 0s 35ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-591785366397> in <module>
#      10   ax.add_patch(rect)
#      11 plt.show()
# ---> 12 for key, value in face['keypoints'].item():
#      13   dot=plt.Circle(value, radius=2, color='red')
#      14   ax.add_patch()
#
# AttributeError: 'dict' object has no attribute 'item'

# %%
url='/content/images.jpg'
pixels= plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(plt.imread(url))
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height, fill = False, color = 'red')
  ax.add_patch(rect)
for key, value in face['keypoints'].items():
   dot =plt.Circle(value, radius=1, color='red')
   ax.add_patch(dot)
plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 278ms/step

# %%
url='/content/images (1).jpg'
pixels= plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(plt.imread(url))
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height, fill = False, color = 'red')
  ax.add_patch(rect)
for key, value in face['keypoints'].items():
   dot =plt.Circle(value, radius=2, color='red')
   ax.add_patch(dot)
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 37ms/step

# %%
import numpy as np
from mtcnn import MTCNN

# %%
x1, y1, width, height = result['box']
x2, y2 = x1 + width, y1 + height
# extract face
face = data[y1:y2, x1:x2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-55317ca22662> in <module>
# ----> 1 x1, y1, width, height = result['box']
#       2 x2, y2 = x1 + width, y1 + height
#       3 # extract face
#       4 face = data[y1:y2, x1:x2]
#
# NameError: name 'result' is not defined

# %%
filename='/content/images (1).jpg'
pixels= plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixels)
draw_faces(filename, faces)
# Out:
# ...
# 2/2 [==============================] - 0s 33ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-5d5a14247325> in <module>
#       3 detector=MTCNN()
#       4 faces=detector.detect_faces(pixels)
# ----> 5 draw_faces(filename, faces)
#
# NameError: name 'draw_faces' is not defined

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x,y,width,height = result_list[i]['box']
    x1,y1 = x + width, y + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y:y1,x:x1])
  plt.show()

filename = '/content/images.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_faces(filename,faces)
# Out:
# ...
# 1/1 [==============================] - 0s 131ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x,y,width,height = result_list[i]['box']
    x1,y1 = x + width, y + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y:y1,x:x1])
  plt.show()

filename = '/content/images (1).jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_faces(filename,faces)
# Out:
# ...
# 2/2 [==============================] - 1s 98ms/step

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Input
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/tải xuống (2).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
plt.show(img)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02129165', 'lion', 0.9985297), ('n02112137', 'chow', 0.0009693595), ('n02108551', 'Tibetan_mastiff', 0.00016874462)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=False)

img_path = '/content/tải xuống (2).jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 631ms/step
