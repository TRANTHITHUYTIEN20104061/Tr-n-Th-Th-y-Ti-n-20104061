# %% [markdown]
# <a href="https://colab.research.google.com/github/TRANTHITHUYTIEN20104061/Tr-n-Th-Th-y-Ti-n-20104061/blob/main/Bu%E1%BB%95i2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
wb = Workbook()
sheet = wb.active
sheet ['A1']='Thuy Tien'
sheet ['B1']= '20104061'
sheet ['A2'] ='Lam Nhu'
sheet ['B2']= '20104052'
wb.save('\Sinhvien.xlsx')

# %% [markdown]
# # Mục mới

# %% [markdown]
# # Mục mới

# %%
import openpyxl
Wb= openpyxl.load_workbook('Sinhvien.xlsx')
sheet= Wb.active
t1= sheet['A1']
t2= sheet['B1']
t3= sheet.cell( row=2, column=1)
t4= sheet.cell( row=2, column=2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Lam Nhu 20104052
# None None

# %%
import openpyxl
wb= openpyxl.Workbook()
sheet = wb.active
c1= sheet.cell( row = 1, column=1)
c1.value= "Trần Thị Thủy Tiên"
c2= sheet.cell( row = 1, column=2)
c2.value= "Nguyễn Thị Xíu"
c3= sheet['A2']
c3.value= "SAN"
c4=sheet['B2']
c4.value= "genovo"
wb.save('xiu.xlsx')

# %%
import openpyxl
wb= openpyxl.Workbook()
sheet = wb.active
wb.create_sheet(index =1, title= "KCN")
wb.save('xiu.xlsx')

# %%
import openpyxl
Wb= openpyxl.load_workbook('Sinhvien.xlsx')
sheet= Wb.active
print(sheet.max_column)
# Out:
# 2

# %%
import openpyxl
Wb= openpyxl.load_workbook('Sinhvien.xlsx')
sheet= Wb.active
print(sheet.max_row)
# Out:
# 1

# %%
Wb= openpyxl.load_workbook('/content/Sinhvien.xlsx')
sheet= Wb.active
maxcl= sheet.max_column
for i in range(1, maxcl+1):
  cell= sheet.cell( row= 1, column= i)
  print(cell.value)
# Out:
# Lam Nhu
# 20104052

# %%
Wb= openpyxl.load_workbook('/content/\Sinhvien.xlsx')
sheet= Wb.active
maxcl= sheet.max_column
for i in range(1, maxcl+1):
  cell= sheet.cell( row= 2, column= i)
  print(cell.value, end =" ")
# Out:
# Lam Nhu 20104052

# %%
Wb= openpyxl.load_workbook('/content/Sinhvien.xlsx')
sheet= Wb.active
maxrow= sheet.max_row
for i in range(1, maxrow+1):
  cell= sheet.cell( row= i, column= 1)
  print(cell.value)
# Out:
# Lam Nhu

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y=x+1
plt.plot(x,y, 'o--')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(6)
y=x+1
plt.plot(x,y, 'o--')
plt.plot(x,-y, 'o-')
plt.title('y=x và y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.grid('on')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x=np.linspace(0,15,16)
y=np.logspace(0.1,2,16)
plt.plot(x,y,'--o')
plt.grid('on')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(25)

plt.plot(x,[(y**3+1)for y in x])
plt.show()

# %%
x=np.arange(25)

plt.plot(x,(x**3+1))
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(7)
plt.plot(x,-x**2,x,-x**3,x,-2*x,x,-2**x)
plt.grid(True)
plt.savefig('Xiu.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(3)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,x**3+1, color='r')
plt.subplot(2,2,2)
plt.plot(x,-x**2, color='g')
plt.subplot(2,2,3)
plt.plot(x,2**x, color='b')
plt.subplot(2,2,4)
plt.plot(x,x*8, color='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.axis([0,100,0,10])
plt.scatter(60,5,s=1000, color='black',alpha=1)
plt.scatter(80,5,s=10, color='b',alpha=0.5)
plt.scatter(100,5,s=1000, color='r',alpha=0.1)
plt.show()

# %%
plt.plot([1,3],[1,3],color='r')
plt.text(2,3.25,"Xiu")
plt.arrow(1.25,2, 0.75 ,0, head_length=0.25, head_width=0.2, color='g')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.barh(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0], color='b',width=0.25)
plt.bar(x+0.25,y[1], color='y', width=0.25)
plt.bar(x+0.5,y[2], color='r', width=0.23)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.random.rand(3,4)

plt.barh(y+0, x[0], color='b',width=0.2)
plt.barh(y+0.25,x[1], color='y', width=0.2)
plt.barh(y+0.5,x[2], color='r', width=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-4178c9c7a2a8> in <module>
#       3 y=np.random.rand(3,4)
#       4
# ----> 5 plt.barh(y+0, x[0], color='b',width=0.2)
#       6 plt.barh(y+0.25,x[1], color='y', width=0.2)
#       7 plt.barh(y+0.5,x[2], color='r', width=0.5)
#
# TypeError: barh() got multiple values for argument 'width'

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
color=np.random.rand(N)
size=20
plt.scatter(x,y,s=size, c=color, alpha=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Mục mới
